# %% [markdown]
# ====== Nguồn http://users.soict.hust.edu.vn/khoattq/ml-dm-course/ ======
#
#
#
# # Bài toán
# - Cần đánh giá hiệu quả của một mô hình phân loại?
# - So sánh hiệu quả của 2 mô hình khác nhau?
#
# Nhưng ta chỉ có một tập dữ liệu đã thu thập được. Để trả lời hai câu hỏi trên thì cần thực hiện bước "Lựa chọn tham số" của mô hình đã chọn.
#
# Bài này sẽ hướng dẫn cách thực hiện từng bước chi tiết, từ <b>lựa chọn tham số</b> (sử dụng Cross validation), cho đến <b>đánh giá</b> (sử dụng Holdout) và <b>so sánh</b> hai mô hình khác nhau. Tập dữ liệu sử dụng là tập văn bản đã thu thập được ở Bài học số 2 (tập tin tức từ Vnexpress).

# %% [markdown]
# ## Mục lục
# - Load dữ liệu từ thư mục
# - Tiền xử lý dữ liệu
# - Lựa chọn tham số các mô hình
# - So sánh SVM và Random Forest

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import learning_curve
from tqdm import tqdm

from sklearn.datasets import load_files
from pyvi import ViTokenizer

from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay

# %matplotlib inline
# Out:
# c:\Users\tonyb\miniconda3\envs\ml\Lib\site-packages\pyvi\ViTokenizer.py:24: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   model = pickle.load(fin)

# %% [markdown]
# ## 1. Load dữ liệu từ thư mục
#
# Giả sử cấu trúc thư mục như sau
#
# - data/news_vnexpress/
#
#     - Kinh tế:
#         - bài báo 1.txt
#         - bài báo 2.txt
#     - Pháp luật
#         - bài báo 3.txt
#         - bài báo 4.txt

# %%
INPUT = 'data/news_1135'
os.makedirs("images",exist_ok=True)  # thư mục lưu các hình ảnh kết quả trong quá trình huấn luyện và đánh giá

# %%
# statistics
print('Các nhãn và số văn bản tương ứng trong dữ liệu')
print('----------------------------------------------')
n = 0
for label in os.listdir(INPUT):
    print(f'{label}: {len(os.listdir(os.path.join(INPUT, label)))}')
    n += len(os.listdir(os.path.join(INPUT, label)))

print('-------------------------')
print(f"Tổng số văn bản: {n}")
# Out:
# Các nhãn và số văn bản tương ứng trong dữ liệu
# ----------------------------------------------
# Giải trí: 0
# Khoa học - Công nghệ: 0
# Kinh tế: 0
# Pháp luật: 0
# Sức khỏe: 70
# Thể thao: 140
# Thời sự: 14
# -------------------------
# Tổng số văn bản: 224

# %%
# load data
data_train = load_files(container_path=INPUT, encoding="utf-8")

print('mapping:')
for i in range(len(data_train.target_names)):
    print(f'{data_train.target_names[i]} - {i}')

print('--------------------------')
print(data_train.filenames[0:1])
print(data_train.target[0:1])
print(data_train.data[0:1])

print("\nTổng số  văn bản: {}" .format( len(data_train.filenames)))
# Out:
# mapping:
# Giải trí - 0
# Khoa học - Công nghệ - 1
# Kinh tế - 2
# Pháp luật - 3
# Sức khỏe - 4
# Thể thao - 5
# Thời sự - 6
# --------------------------
# ['data/news_1135\\Thể thao\\2e62de81ade8318f66cc740f5ede5607ea1bf002.txt']
# [5]
# ['Dân_trí Sáng 5/12 , giải quần_vợt các tay_vợt xuất_sắc Việt_Nam - Cúp Vietravel 2016 đã chính_thức khai_mạc tại TP Vinh - Nghệ_An . Tham_dự giải hơn 30 tay_vợt xuất_sắc nhất của Liên_đoàn quần_vợt Việt_Nam . Dự lễ khai_mạc có ông Nguyễn Trọng Hổ - Vụ_trưởng Vụ thể_thao thành_tích cao II ; Đoàn Quốc Cường - Trưởng bộ_môn quần_vợt Liên_đoàn quần_vợt Việt_Nam ; Nguyễn Quốc Kỳ - Tổng_Giám_đốc Viettravel , Phó_Chủ_tịch kiêm Tổng_thư_ký Liên_đoàn quần_vợt Việt_Nam cùng lãnh_đạo tỉnh Nghệ_An . Giải quần_vợt các cây_vợt xuất_sắc Việt_Nam - Cup Vietravel 2016 do Liên_đoàn Quần_vợt Việt_Nam VTF phối_hợp với Sở VH - TT - DL và Liên_đoàn quần_vợt Nghệ_An NTF tổ_chức ; là giải đấu chuyên_nghiệp quốc_gia lần đầu_tiên được tổ_chức tại Nghệ_An . Ông Nguyễn Quốc Kỳ - PCT kiêm TTK Liên_đoàn quần_vợt Việt_Nam Tham_gia giải lần này có 22 VĐV nam , 9 VĐV nữ có điểm xếp_hạng cao nhất của bộ_môn quần_vợt chuyên_nghiệp , đến từ các trung_tâm quần_vợt lớn trong cả nước như : Thành_phố Hồ Chí Minh ; Bình_Dương ; Hà_Nội , Đà_Nẵng ... Trong đó , những tên_tuổi lớn của làng quần_vợt chuyên_nghiệp Việt_Nam như : Lý Hoàng Nam ; Phạm Minh Tuấn ; Hoàng Thành_Trung ; Trịnh Linh Giang ; Trần Thị Tâm Hảo ; Nguyễn Thị Bé Xuyên ... Các VĐV thi_đấu ở 4 nội_dung gồm : Đơn_nam ; đôi_nam ; đơn_nữ và đôi_nữ theo thể_thức đấu_loại trực_tiếp . Giải đấu là dịp để khích_lệ phong_trào tập_luyện môn Tennis trên địa_bàn tỉnh , là cơ_sở để Nghệ_An hướng đến tổ_chức những giải đấu lớn của quần_vợt chuyên_nghiệp Việt_Nam trong thời_gian tới ; góp_phần quảng_bá hình_ảnh quê_hương Nghệ_An đến với khán_giả cả nước . Phát_biểu tại lễ khai_mạc , ông Huỳnh Thanh_Điền - Phó_Chủ_tịch UBND tỉnh Nghệ_An khẳng_định : Giải quần_vợt các cây_vợt xuất_sắc Việt_Nam Cúp Vietravel 2016 lần đầu_tiên được tổ_chức tại Nghệ_An là bước_tiến mới của phong_trào phát_triển môn quần_vợt tại tỉnh Nghệ_An . Đây là dịp để góp_phần quảng_bá hình_ảnh quê_hương Chủ_tịch Hồ Chí Minh đến với khán_giả cả nước . Giải đấu cũng là cơ_hội rất tốt để Liên_đoàn quần_vợt Nghệ_An ( NTF ) nâng_cao vị_thế của mình trong làng quần_vợt cả nước . Giải Quần_vợt các cây_vợt xuất_sắc Việt_Nam Cúp Vietravel 2016 khởi tranh vòng đấu bảng vào ngày 5-10 / 12 tại sân CLB Trường_Sơn , TP Vinh . Tổng_giá_trị tiền_thưởng lên tới trên 300 triệu đồng . Dịp này , Ban tổ_chức giải đã trao 10 triệu đồng ủng_hộ Trung_tâm bảo_trợ xã_hội tỉnh Nghệ_An . Nguyễn Duy']
#
# Tổng số  văn bản: 224

# %% [markdown]
# ## 2. Tiền xử lý dữ liệu:
# ### 2.1. Chuyển dữ liệu dạng text về dạng số
# Chuyển dữ liệu dạng text về ma trận (n x m) bằng TF. Chuyển nhãn các văn bản về dạng số

# %%
# load dữ liệu các stopwords 
with open("data/vietnamese-stopwords.txt", encoding="utf-8") as f:
    stopwords = f.readlines()
stopwords = [x.strip().replace(" ", "_") for x in stopwords] 
print(f"Số lượng stopwords: {len(stopwords)}")
print(stopwords[:10])

# Chuyển hoá dữ liệu text về dạng vector TF 
#     - loại bỏ từ dừng
#     - sinh từ điển
module_count_vector = CountVectorizer(stop_words=stopwords)
model_rf_preprocess = Pipeline([('vect', module_count_vector),
                    ('tf', TfidfTransformer()),
                    ])
# Hàm thực hiện chuyển đổi dữ liệu text thành dữ liệu số dạng ma trận 
# Input: Dữ liệu 2 chiều dạng numpy.array, mảng nhãn id dạng numpy.array 
data_preprocessed = model_rf_preprocess.fit_transform(data_train.data, data_train.target)

print(f"\nSố lượng từ trong từ điển: {len(module_count_vector.vocabulary_)}")
print(f"Kích thước dữ liệu sau khi xử lý: {data_preprocessed.shape}")
print(f"Kích thước nhãn tương ứng: {data_train.target.shape}")
# Out:
# Số lượng stopwords: 2063
# ['a_lô', 'a_ha', 'ai', 'ai_ai', 'ai_nấy', 'ai_đó', 'alô', 'amen', 'anh', 'anh_ấy']
#
# Số lượng từ trong từ điển: 7972
# Kích thước dữ liệu sau khi xử lý: (224, 7972)
# Kích thước nhãn tương ứng: (224,)

# %% [markdown]
# ### 2.2. Chia dữ liệu thành tập train và test
# (Nghĩa là ta sẽ dùng Holdout để đánh giá hiệu quả của một mô hình)

# %%
p = 0.2
pivot = int(data_preprocessed.shape[0] * (1-0.2))
X_train, X_test = data_preprocessed[0:pivot], data_preprocessed[pivot:]
Y_train, Y_test = data_train.target[0:pivot], data_train.target[pivot:]

# %% [markdown]
# # 3. Lựa chọn (tối ưu) tham số
#
# Chỉ dùng tập train để thực hiện lựa chọn tham số.
# - SVM: kernel, C
# - Random Forest: criteria, N
#
# Ta sẽ dùng chiến lược Cross Validation trong bước này.

# %%
def cross_validation(estimator, X_train, Y_train, scoring='accuracy'):
    _, train_scores, test_scores = learning_curve(estimator, X_train, Y_train, cv=10, n_jobs=-1, train_sizes=[1.0, ], scoring=scoring)
    test_scores = test_scores[0]
    mean, std = test_scores.mean(), test_scores.std()
    return mean, std

def plot(title, xlabel, X, Y, error, ylabel = "Accuracy"):
    plt.xlabel(xlabel)
    plt.title(title)
    plt.grid()
    plt.ylabel(ylabel)
    plt.errorbar(X, Y, error, linestyle='None', marker='o')

# %% [markdown]
# ## 3.1. Đánh giá hiệu quả của các kernel trong SVM

# %%
title = "thay đổi kernel, C = 1"
xlabel = "kernel"
X = []
Y = []
error = []

for kernel in tqdm(['linear', 'poly', 'rbf', 'sigmoid']):
    # Với mỗi kernel được chọn, 
    # thực hiện xây dựng mô hình, huấn luyện và đánh giá theo cross-validation
    text_clf = svm.SVC(kernel=kernel, C=1.0)
    mean, std = cross_validation(text_clf, X_train, Y_train)
    X.append(kernel)
    Y.append(mean)
    error.append(std)

# lưu kết quả ra file ảnh 
plot(title, xlabel, X, Y, error)
plt.savefig('images/svm_change_kernel.png', bbox_inches='tight')
plt.show()
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# c:\Users\tonyb\miniconda3\envs\ml\Lib\site-packages\sklearn\model_selection\_split.py:813: UserWarning: The least populated class in y has only 9 members, which is less than n_splits=10.
#   warnings.warn(
#  25%|██▌       | 1/4 [00:03<00:11,  3.75s/it]c:\Users\tonyb\miniconda3\envs\ml\Lib\site-packages\sklearn\model_selection\_split.py:813: UserWarning: The least populated class in y has only 9 members, which is less than n_splits=10.
#   warnings.warn(
#  50%|█████     | 2/4 [00:06<00:05,  2.97s/it]c:\Users\tonyb\miniconda3\envs\ml\Lib\site-packages\sklearn\model_selection\_split.py:813: UserWarning: The least populated class in y has only 9 members, which is less than n_splits=10.
#   warnings.warn(
#  75%|███████▌  | 3/4 [00:06<00:01,  1.71s/it]c:\Users\tonyb\miniconda3\envs\ml\Lib\site-packages\sklearn\model_selection\_split.py:813: UserWarning: The least populated class in y has only 9 members, which is less than n_splits=10.
#   warnings.warn(
# 100%|██████████| 4/4 [00:06<00:00,  1.63s/it]

# %% [markdown]
# ## 3.2. Đánh giá ảnh hưởng của tham số C trong SVM

# %%
title = "thay đổi C, kernel = linear"
xlabel = "C"
X = []
Y = []
error = []

for C in tqdm([.1, 1.0, 2.0, 5.0, 10.0]):
    # Với từng giá trị C nhận được, 
    # thực hiện xây dựng mô hình, huấn luyện và đánh giá theo cross-validation
    text_clf = svm.SVC(kernel='linear', C=C)
    mean, std = cross_validation(text_clf, X_train, Y_train)
    X.append(str(C))
    Y.append(mean)
    error.append(std)

# lưu kết quả ra file ảnh
plot(title, xlabel, X, Y, error)
plt.savefig('images/svm_change_C.png', bbox_inches='tight')
plt.show()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]c:\Users\tonyb\miniconda3\envs\ml\Lib\site-packages\sklearn\model_selection\_split.py:813: UserWarning: The least populated class in y has only 9 members, which is less than n_splits=10.
#   warnings.warn(
#  20%|██        | 1/5 [00:00<00:00,  5.64it/s]c:\Users\tonyb\miniconda3\envs\ml\Lib\site-packages\sklearn\model_selection\_split.py:813: UserWarning: The least populated class in y has only 9 members, which is less than n_splits=10.
#   warnings.warn(
#  40%|████      | 2/5 [00:00<00:00,  5.92it/s]c:\Users\tonyb\miniconda3\envs\ml\Lib\site-packages\sklearn\model_selection\_split.py:813: UserWarning: The least populated class in y has only 9 members, which is less than n_splits=10.
#   warnings.warn(
#  60%|██████    | 3/5 [00:00<00:00,  5.98it/s]c:\Users\tonyb\miniconda3\envs\ml\Lib\site-packages\sklearn\model_selection\_split.py:813: UserWarning: The least populated class in y has only 9 members, which is less than n_splits=10.
#   warnings.warn(
#  80%|████████  | 4/5 [00:00<00:00,  6.02it/s]c:\Users\tonyb\miniconda3\envs\ml\Lib\site-packages\sklearn\model_selection\_split.py:813: UserWarning: The least populated class in y has only 9 members, which is less than n_splits=10.
#   warnings.warn(
# 100%|██████████| 5/5 [00:00<00:00,  6.03it/s]

# %% [markdown]
# ## 3.3. Đánh giá ảnh hưởng của độ đo trong Random Forest

# %%
title = "thay đổi criterion, n_estimators = 50"
xlabel = "criterion"
X = []
Y = []
error = []

for criterion in tqdm(["gini", "entropy"]):
    # Với mỗi criterion nhận được,
    # thực hiện xây dựng mô hình, huấn luyện và đánh giá theo cross-validation
    text_clf = RandomForestClassifier(criterion=criterion, n_estimators=50)
    mean, std = cross_validation(text_clf, X_train, Y_train)
    X.append(str(criterion))
    Y.append(mean)
    error.append(std)

# lưu kết quả ra file ảnh
plot(title, xlabel, X, Y, error)
plt.savefig('images/RF_change_criterion.png', bbox_inches='tight')
plt.show()
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]c:\Users\tonyb\miniconda3\envs\ml\Lib\site-packages\sklearn\model_selection\_split.py:813: UserWarning: The least populated class in y has only 9 members, which is less than n_splits=10.
#   warnings.warn(
#  50%|█████     | 1/2 [00:00<00:00,  2.94it/s]c:\Users\tonyb\miniconda3\envs\ml\Lib\site-packages\sklearn\model_selection\_split.py:813: UserWarning: The least populated class in y has only 9 members, which is less than n_splits=10.
#   warnings.warn(
# 100%|██████████| 2/2 [00:00<00:00,  3.35it/s]

# %% [markdown]
# ## 3.4. Đánh giá ảnh hưởng của số cây trong Random Forest

# %%
title = "thay đổi n_estimators, criterion = gini"
xlabel = "n_estimators"
X = []
Y = []
error = []

for n_estimators in tqdm([10, 50, 100, 300]):
    # Với từng giá trị n_estimators nhận được,
    # thực hiện xây dựng mô hình, huấn luyện và đánh giá theo cross-validation
    text_clf = RandomForestClassifier(criterion='gini', n_estimators=n_estimators)
    mean, std = cross_validation(text_clf, X_train, Y_train)
    X.append(str(n_estimators))
    Y.append(mean)
    error.append(std)

# lưu kết quả ra file ảnh
plot(title, xlabel, X, Y, error)
plt.savefig('images/RF_change_N.png', bbox_inches='tight')
plt.show()
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]c:\Users\tonyb\miniconda3\envs\ml\Lib\site-packages\sklearn\model_selection\_split.py:813: UserWarning: The least populated class in y has only 9 members, which is less than n_splits=10.
#   warnings.warn(
# c:\Users\tonyb\miniconda3\envs\ml\Lib\site-packages\sklearn\model_selection\_split.py:813: UserWarning: The least populated class in y has only 9 members, which is less than n_splits=10.
#   warnings.warn(
#  50%|█████     | 2/4 [00:00<00:00,  6.70it/s]c:\Users\tonyb\miniconda3\envs\ml\Lib\site-packages\sklearn\model_selection\_split.py:813: UserWarning: The least populated class in y has only 9 members, which is less than n_splits=10.
#   warnings.warn(
#  75%|███████▌  | 3/4 [00:00<00:00,  4.60it/s]c:\Users\tonyb\miniconda3\envs\ml\Lib\site-packages\sklearn\model_selection\_split.py:813: UserWarning: The least populated class in y has only 9 members, which is less than n_splits=10.
#   warnings.warn(
# 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]

# %% [markdown]
# ## 3.5. Đánh giá ảnh tham số K trong mô hình KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

title = "thay đổi K"
xlabel = "K"
X = []
Y = []
error = []

for k in tqdm([1, 3, 5, 20, 50]):
    # Với từng giá trị k nhận được,
    # thực hiện xây dựng mô hình, huấn luyện và đánh giá theo cross-validation
    text_clf = KNeighborsClassifier(n_neighbors=k)
    mean, std = cross_validation(text_clf, X_train, Y_train)
    X.append(str(k))
    Y.append(mean)
    error.append(std)

# lưu kết quả ra file ảnh
plot(title, xlabel, X, Y, error)
plt.savefig('images/KNN_change_K.png', bbox_inches='tight')
plt.show()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]c:\Users\tonyb\miniconda3\envs\ml\Lib\site-packages\sklearn\model_selection\_split.py:813: UserWarning: The least populated class in y has only 9 members, which is less than n_splits=10.
#   warnings.warn(
# c:\Users\tonyb\miniconda3\envs\ml\Lib\site-packages\sklearn\model_selection\_split.py:813: UserWarning: The least populated class in y has only 9 members, which is less than n_splits=10.
#   warnings.warn(
# c:\Users\tonyb\miniconda3\envs\ml\Lib\site-packages\sklearn\model_selection\_split.py:813: UserWarning: The least populated class in y has only 9 members, which is less than n_splits=10.
#   warnings.warn(
#  60%|██████    | 3/5 [00:00<00:00, 21.62it/s]c:\Users\tonyb\miniconda3\envs\ml\Lib\site-packages\sklearn\model_selection\_split.py:813: UserWarning: The least populated class in y has only 9 members, which is less than n_splits=10.
#   warnings.warn(
# c:\Users\tonyb\miniconda3\envs\ml\Lib\site-packages\sklearn\model_selection\_split.py:813: UserWarning: The least populated class in y has only 9 members, which is less than n_splits=10.
#   warnings.warn(
# 100%|██████████| 5/5 [00:00<00:00, 22.98it/s]

# %% [markdown]
# # 4. So sánh các mô hình
# - Sau khi chọn được các bộ tham số tốt nhất cho mỗi mô hình, ta huấn luyện lại trên toàn bộ tập Train.
# - Dùng các mô hình mới huấn luyện để phán đoán cho các dữ liệu trong tập Test
# - Đo đạc Độ chính xác (Accuracy) của chúng và so sánh kết quả.

# %%
svm_ = svm.SVC(kernel='linear', C=1.0)
rf = RandomForestClassifier(criterion='gini', n_estimators=300)
knn = KNeighborsClassifier(n_neighbors=5)

# Huấn luyện các mô hình trên tập dữ liệu train đầy đủ
svm_.fit(X_train, Y_train)
rf.fit(X_train, Y_train)
knn.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier()

# %%
# Kết quả dự đoán trên tập test
print(f'SVM: {accuracy_score(Y_test, svm_.predict(X_test))}')
print(f'RF: {accuracy_score(Y_test, rf.predict(X_test))}')
print(f'KNN: {accuracy_score(Y_test, knn.predict(X_test))}')
# Out:
# SVM: 0.9111111111111111
# RF: 0.8888888888888888
# KNN: 0.9555555555555556

# %%
np.unique(Y_test)
# Out:
# array([4, 5, 6])

# %%
ConfusionMatrixDisplay.from_estimator(svm_, X_test, Y_test)

# %%
ConfusionMatrixDisplay.from_estimator(rf, X_test, Y_test)

# %%
ConfusionMatrixDisplay.from_estimator(knn, X_test, Y_test)

# %% [markdown]
# # 5. Bài tập
# - Sử dụng dữ liệu đánh giá tín dụng cá nhân
# - Sử dụng độ đo đánh giá negative cost
# - Lựa chọn tham số cho các mô hình SVM, Random Forest và KNN
# - So sánh các mô hình với siêu tham số tốt nhất

# %%
data = np.genfromtxt('..\ex 5\data\german.data-numeric')
X_data = data[:,:24]
Y_data = data[:,-1]
print(X_data.shape)
print(Y_data.shape)
# Out:
# (1000, 24)
# (1000,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_data, Y_data, test_size=0.2, random_state=42)

# %%
# Hàm tính neg_cost, dùng để truyền vào scoring của learning_curve
def neg_cost(estimator, X, y):
    y_true = y
    y_pred = estimator.predict(X)
    true_pos = ((y_true==y_pred)&(y_true==1.0))*0.0
    true_ne = ((y_true==y_pred)&(y_true==2.0))*0.0
    false_ne = ((y_true!=y_pred)&(y_true==1.0))*1.0
    false_pos = ((y_true!=y_pred)&(y_true==2.0))*5.0
    return -sum(true_pos + true_ne + false_pos + false_ne)/len(y_true)

# %% [markdown]
# ### 5.1 Đánh giá ảnh hưởng của kernel trong svm

# %%
title = "thay đổi kernel, C = 1"
xlabel = "kernel"
X = []
Y = []
error = []

for kernel in tqdm(['linear', 'poly', 'rbf', 'sigmoid']):
    # Với mỗi kernel được chọn, 
    # thực hiện xây dựng mô hình, huấn luyện và đánh giá theo cross-validation
    credit_clf = svm.SVC(kernel=kernel, C=1.0)
    mean, std = cross_validation(credit_clf, X_train, y_train, neg_cost)
    X.append(kernel)
    Y.append(mean)
    error.append(std)

plot(title, xlabel, X, Y, error, "Negative Cost")
plt.show()
# Out:
# 100%|██████████| 4/4 [00:00<00:00,  6.20it/s]

# %% [markdown]
# ### 5.2 Đánh giá ảnh hưởng của tham số C trong svm

# %%
title = "thay đổi C, kernel = linear"
xlabel = "C"
X = []
Y = []
error = []

for C in tqdm([.1, 1.0, 2.0, 5.0, 10.0]):
    # Với từng giá trị C nhận được, 
    # thực hiện xây dựng mô hình, huấn luyện và đánh giá theo cross-validation
    credit_clf = svm.SVC(kernel='linear', C=C)
    mean, std = cross_validation(credit_clf, X_train, y_train, neg_cost)
    X.append(str(C))
    Y.append(mean)
    error.append(std)

# lưu kết quả ra file ảnh
plot(title, xlabel, X, Y, error, "Negative Cost")
#plt.savefig('images/svm_change_C.png', bbox_inches='tight')
plt.show()
# Out:
# 100%|██████████| 5/5 [00:11<00:00,  2.28s/it]

# %% [markdown]
# ### 5.3 Đánh giá ảnh hưởng của độ đo trong Random Forest

# %%
title = "thay đổi criterion, n_estimators = 50"
xlabel = "criterion"
X = []
Y = []
error = []

for criterion in tqdm(["gini", "entropy"]):
    # Với mỗi criterion nhận được,
    # thực hiện xây dựng mô hình, huấn luyện và đánh giá theo cross-validation
    text_clf = RandomForestClassifier(criterion=criterion, n_estimators=50)
    mean, std = cross_validation(text_clf, X_train, y_train, neg_cost)
    X.append(str(criterion))
    Y.append(mean)
    error.append(std)

# lưu kết quả ra file ảnh
plot(title, xlabel, X, Y, error, "Negative Cost")
#plt.savefig('images/RF_change_criterion.png', bbox_inches='tight')
plt.show()
# Out:
# 100%|██████████| 2/2 [00:00<00:00,  4.20it/s]

# %% [markdown]
# ### 5.4 Đánh giá ảnh hưởng của số cây trong Random Forest

# %%
title = "thay đổi n_estimators, criterion = gini"
xlabel = "n_estimators"
X = []
Y = []
error = []

for n_estimators in tqdm([10, 50, 100, 300]):
    # Với từng giá trị n_estimators nhận được,
    # thực hiện xây dựng mô hình, huấn luyện và đánh giá theo cross-validation
    text_clf = RandomForestClassifier(criterion='gini', n_estimators=n_estimators)
    mean, std = cross_validation(text_clf, X_train, y_train, neg_cost)
    X.append(str(n_estimators))
    Y.append(mean)
    error.append(std)

# lưu kết quả ra file ảnh
plot(title, xlabel, X, Y, error, "Negative Cost")
#plt.savefig('images/RF_change_N.png', bbox_inches='tight')
plt.show()
# Out:
# 100%|██████████| 4/4 [00:00<00:00,  4.80it/s]

# %% [markdown]
# ### 5.5 Đánh giá ảnh hưởng của hệ số k trong KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

title = "thay đổi K"
xlabel = "K"
X = []
Y = []
error = []

for k in tqdm([1, 3, 5, 20, 50]):
    # Với từng giá trị k nhận được,
    # thực hiện xây dựng mô hình, huấn luyện và đánh giá theo cross-validation
    text_clf = KNeighborsClassifier(n_neighbors=k)
    mean, std = cross_validation(text_clf, X_train, y_train, neg_cost)
    X.append(str(k))
    Y.append(mean)
    error.append(std)

# lưu kết quả ra file ảnh
plot(title, xlabel, X, Y, error, "Negative Cost")
#plt.savefig('images/KNN_change_K.png', bbox_inches='tight')
plt.show()
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 12.60it/s]

# %% [markdown]
# ### 5.6 So sánh các model

# %%
svm_ = svm.SVC(kernel='linear', C=1.0)
rf = RandomForestClassifier(criterion='gini', n_estimators=50)
knn = KNeighborsClassifier(n_neighbors=5)

svm_.fit(X_train, y_train)
rf.fit(X_train, y_train)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
print(f"Negative cost SVM: {neg_cost(svm_, X_test, y_test)}")
print(f"Negative cost RF: {neg_cost(rf, X_test, y_test)}")
print(f"Negative cost KNN: {neg_cost(knn, X_test, y_test)}")
# Out:
# Negative cost SVM: -0.88
# Negative cost RF: -0.905
# c:\Users\tonyb\miniconda3\envs\ml\Lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#   warnings.warn(msg, RuntimeWarning)
# Negative cost KNN: -1.31
